# %%
import numpy as np
import pandas as pd

# %%
 ## this need to change for everyone
df = pd.read_csv("/Users/zoewilliams/Desktop/Intro to Data Science/Movies.csv")

# %%
df.shape #view starting dimensions
# Out:
# (1048575, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 18 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   movie_id              1048575 non-null  int64
#  1   title                 1048562 non-null  object
#  2   vote_average          1048575 non-null  float64
#  3   vote_count            1048575 non-null  int64
#  4   status                1048575 non-null  object
#  5   release_date          899153 non-null   object
#  6   revenue               1048575 non-null  int64
#  7   adult                 1048575 non-null  bool
#  8   budget                1048575 non-null  int64
#  9   imdb_id               576991 non-null   object
#  10  original_language     1048575 non-null  object
#  11  original_title        1048562 non-null  object
#  12  overview              850351 non-null   object
#  13  popularity            1048575 non-null  float64
# ...

# %%
print(df.head()) #View congested dataset
# Out:
#    movie_id            title  vote_average  vote_count    status release_date  \
# 0   4520010        Inception         8.364       34495  Released    7/15/2010
# 1   4520011     Interstellar         8.417       32571  Released    11/5/2014
# 2   4520012  The Dark Knight         8.512       30619  Released    7/16/2008
# 3   4520013           Avatar         7.573       29815  Released   12/15/2009
# 4   4520014     The Avengers         7.710       29166  Released    4/25/2012
#
#       revenue  adult     budget    imdb_id original_language   original_title  \
# 0   825532764  False  160000000  tt1375666                en        Inception
# 1   701729206  False  165000000  tt0816692                en     Interstellar
# 2  1004558444  False  185000000  tt0468569                en  The Dark Knight
# 3  2923706026  False  237000000  tt0499549                en           Avatar
# 4  1518815515  False  220000000  tt0848228                en     The Avengers
#
# ...

# %%
df_sorted = df.sort_values(by="revenue", ascending = False) #Sort by top grossing

# %%
df_sorted.head() #View current dataset sample
# Out:
#         movie_id                    title  vote_average  vote_count    status  \
# 682231   5202241  Adventures in Bora Bora         0.000           0  Released
# 262288   4782298        TikTok Rizz Party        10.000           1  Released
# 551944   5071954                Bee Movie         0.000           0  Released
# 3        4520013                   Avatar         7.573       29815  Released
# 15       4520025        Avengers: Endgame         8.263       23857  Released
#
#        release_date     revenue  adult     budget    imdb_id  \
# 682231    8/23/2023  3000000000  False  800000000        NaN
# 262288     4/1/2024  3000000000  False  250000000        NaN
# 551944          NaN  2930000000  False  150000000        NaN
# 3        12/15/2009  2923706026  False  237000000  tt0499549
# 15        4/24/2019  2800000000  False  356000000  tt4154796
#
#        original_language           original_title  \
# 682231                en  Adventures in Bora Bora
# ...

# %%
print(df.columns)
# Out:
# Index(['movie_id', 'title', 'status', 'release_date', 'revenue', 'adult',
#        'budget', 'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'genres', 'production_companies', 'production_countries',
#        'spoken_languages'],
#       dtype='object')

# %%
df.drop(columns=['overview'], inplace=True)
print(df)
# Out:
#          movie_id                                         title    status  \
# 0         4520010                                     Inception  Released
# 1         4520011                                  Interstellar  Released
# 2         4520012                               The Dark Knight  Released
# 3         4520013                                        Avatar  Released
# 4         4520014                                  The Avengers  Released
# ...           ...                                           ...       ...
# 1048570   5568580                   Master of Demon Subjugation  Released
# 1048571   5568581                   Storybook Classics: Ivanhoe  Released
# 1048572   5568582                                Screen Flicker  Released
# 1048573   5568583                Chamber of Whores 2: Pornworld  Released
# 1048574   5568584  FREEDOMS 9th Anniversary Memorial Conference  Released
#
#         release_date     revenue  adult     budget    imdb_id  \
# ...

# %%
df.drop('release_date', axis=1, inplace=True) #Deleting release date column
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 df.drop('release_date', axis=1, inplace=True) #Deleting release date column
#       2 df.head()
#
# File ~/Downloads/Downloads/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
# ...
