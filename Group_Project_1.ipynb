# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### Data Loading

# %%
df=pd.read_csv("Movies.csv") ## this need to change for everyone
df.head()
# Out:
#    movie_id            title  vote_average  vote_count    status release_date  \
# 0   4520010        Inception         8.364       34495  Released    7/15/2010
# 1   4520011     Interstellar         8.417       32571  Released    11/5/2014
# 2   4520012  The Dark Knight         8.512       30619  Released    7/16/2008
# 3   4520013           Avatar         7.573       29815  Released   12/15/2009
# 4   4520014     The Avengers         7.710       29166  Released    4/25/2012
#
#       revenue  adult     budget    imdb_id original_language   original_title  \
# 0   825532764  False  160000000  tt1375666                en        Inception
# 1   701729206  False  165000000  tt0816692                en     Interstellar
# 2  1004558444  False  185000000  tt0468569                en  The Dark Knight
# 3  2923706026  False  237000000  tt0499549                en           Avatar
# 4  1518815515  False  220000000  tt0848228                en     The Avengers
#
# ...

# %%
df.shape #view starting dimensions
# Out:
# (1048575, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 18 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   movie_id              1048575 non-null  int64
#  1   title                 1048562 non-null  object
#  2   vote_average          1048575 non-null  float64
#  3   vote_count            1048575 non-null  int64
#  4   status                1048575 non-null  object
#  5   release_date          899153 non-null   object
#  6   revenue               1048575 non-null  int64
#  7   adult                 1048575 non-null  bool
#  8   budget                1048575 non-null  int64
#  9   imdb_id               576991 non-null   object
#  10  original_language     1048575 non-null  object
#  11  original_title        1048562 non-null  object
#  12  overview              850351 non-null   object
#  13  popularity            1048575 non-null  float64
# ...

# %%
print(df.head()) #View congested dataset
# Out:
#    movie_id            title  vote_average  vote_count    status release_date  \
# 0   4520010        Inception         8.364       34495  Released    7/15/2010
# 1   4520011     Interstellar         8.417       32571  Released    11/5/2014
# 2   4520012  The Dark Knight         8.512       30619  Released    7/16/2008
# 3   4520013           Avatar         7.573       29815  Released   12/15/2009
# 4   4520014     The Avengers         7.710       29166  Released    4/25/2012
#
#       revenue  adult     budget    imdb_id original_language   original_title  \
# 0   825532764  False  160000000  tt1375666                en        Inception
# 1   701729206  False  165000000  tt0816692                en     Interstellar
# 2  1004558444  False  185000000  tt0468569                en  The Dark Knight
# 3  2923706026  False  237000000  tt0499549                en           Avatar
# 4  1518815515  False  220000000  tt0848228                en     The Avengers
#
# ...

# %%
df_sorted = df.sort_values(by="budget", ascending = False) #Sort by top grossing (we would have done this but the spreadsheet has incorrect values for lower level movie)

# %%
df.head() #View current dataset sample
# Out:
#    movie_id            title  vote_average  vote_count    status release_date  \
# 0   4520010        Inception         8.364       34495  Released    7/15/2010
# 1   4520011     Interstellar         8.417       32571  Released    11/5/2014
# 2   4520012  The Dark Knight         8.512       30619  Released    7/16/2008
# 3   4520013           Avatar         7.573       29815  Released   12/15/2009
# 4   4520014     The Avengers         7.710       29166  Released    4/25/2012
#
#       revenue  adult     budget    imdb_id original_language   original_title  \
# 0   825532764  False  160000000  tt1375666                en        Inception
# 1   701729206  False  165000000  tt0816692                en     Interstellar
# 2  1004558444  False  185000000  tt0468569                en  The Dark Knight
# 3  2923706026  False  237000000  tt0499549                en           Avatar
# 4  1518815515  False  220000000  tt0848228                en     The Avengers
#
# ...

# %% [markdown]
# #### Data Cleaning (Pandas)

# %%
df.drop('release_date', axis=1, inplace=True) #Deleting release date column
df.head()
# Out:
#    movie_id            title  vote_average  vote_count    status     revenue  \
# 0   4520010        Inception         8.364       34495  Released   825532764
# 1   4520011     Interstellar         8.417       32571  Released   701729206
# 2   4520012  The Dark Knight         8.512       30619  Released  1004558444
# 3   4520013           Avatar         7.573       29815  Released  2923706026
# 4   4520014     The Avengers         7.710       29166  Released  1518815515
#
#    adult     budget    imdb_id original_language   original_title  \
# 0  False  160000000  tt1375666                en        Inception
# 1  False  165000000  tt0816692                en     Interstellar
# 2  False  185000000  tt0468569                en  The Dark Knight
# 3  False  237000000  tt0499549                en           Avatar
# 4  False  220000000  tt0848228                en     The Avengers
#
#                                             overview  popularity  \
# ...

# %%
df.drop(["movie_id", "status", "adult", "imdb_id", "original_language", "original_title", "production_companies", "production_countries", "spoken_languages"], axis=1, inplace=True) #Deleting other unnecessary columns

# %%
df.head() #Ensuring the change was made
# Out:
#              title  vote_average  vote_count     revenue     budget  \
# 0        Inception         8.364       34495   825532764  160000000
# 1     Interstellar         8.417       32571   701729206  165000000
# 2  The Dark Knight         8.512       30619  1004558444  185000000
# 3           Avatar         7.573       29815  2923706026  237000000
# 4     The Avengers         7.710       29166  1518815515  220000000
#
#                                             overview  popularity  \
# 0  Cobb, a skilled thief who commits corporate es...      83.952
# 1  The adventures of a group of explorers who mak...     140.241
# 2  Batman raises the stakes in his war on crime. ...     130.643
# 3  In the 22nd century, a paraplegic Marine is di...      79.932
# 4  When an unexpected enemy emerges and threatens...      98.082
#
#                                         genres
# 0           Action, Science Fiction, Adventure
# 1            Adventure, Drama, Science Fiction
# ...

# %%
df.drop(df.index[15:10000000], inplace=True) #Removing excess rows

# %%
df.drop(["overview"], axis=1, inplace=True) #Deleting Overview column

# %%
df.head()
# Out:
#              title  vote_average  vote_count     revenue     budget  \
# 0        Inception         8.364       34495   825532764  160000000
# 1     Interstellar         8.417       32571   701729206  165000000
# 2  The Dark Knight         8.512       30619  1004558444  185000000
# 3           Avatar         7.573       29815  2923706026  237000000
# 4     The Avengers         7.710       29166  1518815515  220000000
#
#    popularity                                       genres
# 0      83.952           Action, Science Fiction, Adventure
# 1     140.241            Adventure, Drama, Science Fiction
# 2     130.643               Drama, Action, Crime, Thriller
# 3      79.932  Action, Adventure, Fantasy, Science Fiction
# 4      98.082           Science Fiction, Action, Adventure

# %%
df.shape
# Out:
# (15, 7)

# %% [markdown]
# #### Sorting and Ranking

# %%
df_sorted = df.sort_values(by="popularity", ascending = False)

# %%
df_sorted #Checking to make sure the change was made
# Out:
#                                        title  vote_average  vote_count  \
# 11  Harry Potter and the Philosopher's Stone         7.916       25379
# 6                     Avengers: Infinity War         8.255       27713
# 1                               Interstellar         8.417       32571
# 2                            The Dark Knight         8.512       30619
# 14                  The Shawshank Redemption         8.702       24649
# 4                               The Avengers         7.710       29166
# 10                              Forrest Gump         8.477       25409
# 0                                  Inception         8.364       34495
# 3                                     Avatar         7.573       29815
# 9                               Pulp Fiction         8.488       25893
# 12                                  Iron Man         7.640       24874
# 5                                   Deadpool         7.606       28894
# ...

# %%
print(df_sorted) #Viewing change in another view
# Out:
#                                        title  vote_average  vote_count  \
# 11  Harry Potter and the Philosopher's Stone         7.916       25379
# 6                     Avengers: Infinity War         8.255       27713
# 1                               Interstellar         8.417       32571
# 2                            The Dark Knight         8.512       30619
# 14                  The Shawshank Redemption         8.702       24649
# 4                               The Avengers         7.710       29166
# 10                              Forrest Gump         8.477       25409
# 0                                  Inception         8.364       34495
# 3                                     Avatar         7.573       29815
# 9                               Pulp Fiction         8.488       25893
# 12                                  Iron Man         7.640       24874
# 5                                   Deadpool         7.606       28894
# ...

# %% [markdown]
# #### Data Export

# %%
df_sorted.to_csv('Group4_Movies.csv', index=False) #Creating new, condensed csv file
